# %% [markdown]
# ython<br>
# heck TDX ticket 894788<br>
#  expected no knowledge. Tutorial. really slow and informtative. <br>
#  setup and coding crash course. <br>
#  syntax. basic python. jupyter. pandas. geopandas. <br>
#  in person for asking questions.  <br>
#  provided links to topics for me. Provided in ticket. <br>
#  timing? Location?

# %% [markdown]
# t the least, I hope the students can learn how to set up an<br>
# python environment, run a jupyter notebook from their own computers, and learn some of the basics of Python.

# %% [markdown]
# how IDE env?

# %%
2+2

# %% [markdown]
# o the lesson in co lab. Similar to jupyter notebook.

# %%
print(2+2)
#Now store into variable name.
#Show a comment. object created as expression
var1 = 2+2

# %% [markdown]
# rinting fun like.

# %%
age_1= 34
Response_ID = 1
print('Participant', Response_ID, 'is', age_1, 'years old.')

# %%
hometown = 'ithaca'

# %% [markdown]
# ype of object

# %%
type(age_1)
type(hometown)

# %% [markdown]
# alculations of objects. This is the foundation. Creativity.

# %%
Later_Age = age_1 + 3
print(Later_Age)

# %% [markdown]
# otice how object name gets overwritten.

# %%
Later_Age = age_1 * 3
print(Later_Age)

# %% [markdown]
#  divide. ** exponent.

# %% [markdown]
# ser created function. Mention variable names get replaced. Does a task that you define. Notice the indent and explain(functions, loops). <br>
# ariables in function are like temporary names.

# %%
def increase_age(starting_age):
    later_age = starting_age + 3
    print("The age after 3 years will be", later_age)

# %% [markdown]
# an be really creative with these too. Essentially do anything you want. Just have to think it.

# %%
increase_age(age_1)

# %% [markdown]
# xercise. Celsius to farenheit. Accept a number in celsius. Or do something similar for exercise.

# %%
def cel_far(celsius):
    faren = ((9/5) * celsius) + 32
    return faren

# %%
cel_far(0)

# %% [markdown]
# lready created functions. This is where you use your resources. Research what stuff means. Pre-defined functions.

# %%
round(5.389, 1)
help(round)

# %% [markdown]
# hen talk a bit about lists.

# %%
list = [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ore about pre-created functions.

# %%
min(list)
sum(list)
len(list)

# %% [markdown]
# ndex list

# %%
print('First element is index 0', list[0])
print('4th element is index 3', list[0])

# %% [markdown]
# everse direction

# %%
print('5th element is index -1', list[-1])

# %% [markdown]
# lice list. [starting:ending]

# %%
rem = list[:4]
print(rem)

# %% [markdown]
# ppend list item:

# %%
list.append(7)
print(list)

# %% [markdown]
# oop and conditionals?<br>
# reate looping item.

# %%
for item in list:
    if item < 3:
        print(item)
    elif item > 3:
        print("Greater than 3")
    else:
        print("The rest")

# %% [markdown]
# xercise. combination of many things done so far.<br>
# reate a list of cities in America. ex Boston. New York. Chicago. Miami.<br>
# rint 2nd to last element of above created list.<br>
# dd international city 'Prague' to list<br>
# onus: Loop through the items in this list and print the cities that contain the letter 'i'<br>
# int. string.find function.<br>
# elpful link. http://net-informations.com/python/basics/contains.htm

# %%
cities = ['Boston', 'New York', 'Chicago', 'Miami']
print(cities[-2])
cities.append('Prague')
for item in cities:
    if item.find('i') != -1:
        print(item)

# %% [markdown]
# andas. Groupby, basic stats, sorting, conditional subsetting. Missing values.

# %%
from pandas import DataFrame, read_csv
import pandas as pd
Location = './data/survey_responses.csv'
df = pd.read_csv(Location)
type(df)
age_column = df['Age']
display(age_column)
multi_columns = df[['Age', 'Living_Location']]
display(multi_columns)
multi_rows = df.loc[[1,2,3,4]]
display(multi_rows)

# %%
print(df["Age"].min()) # what's the age of the youngest participant?
print(df["Age"].max()) # what's the age of the oldest participant?
print(df["Age"].mean()) # what's the average age of participants?

# %%
df[df["Age"] <= 30]

# %%
df_grouped = df.groupby("College")
display(df_grouped["College"].count())

# %% [markdown]
# rop missing values

# %%
data.dropna()

# %% [markdown]
# esources and accessibility. How to replicate this. How can have access to code and will always be able to work. How to run python with code for free and practice resources. <br>
# an launch google colab using link below.

# %% [markdown]
# an access code from this sessions in link below.
